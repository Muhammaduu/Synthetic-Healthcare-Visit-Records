# %% [markdown]
# # Synthetic Healthcare Visit Records
#
# ## M.Abdirisak.A
# ## 22/02/2025

# %%
# import neccessary libraries 
import pandas as pd
import random
from faker import Faker

# %%
# Initialize Faker instance
fake = Faker()
# Predefined lists for possible values
diagnoses = ["Diabetes", "Hypertension", "Heart Disease", "Asthma", "Arthritis"]
treatments = ["Insulin Therapy", "Blood Pressure Medication", "Cardiac Surgery", "Inhaler Therapy", "Physical Therapy"]
doctors = ["Dr. Smith", "Dr. Lee", "Dr. Wilson", "Dr. Johnson", "Dr. Martinez"]
payment_methods = ["Insurance", "Credit Card", "Cash", "Debit Card"]
hospital_locations = ["New York", "Los Angeles", "Chicago", "Houston"]

# List to store generated patient records
data = []
for i in range(1, 101):  # Generate 100 samples
    record = {
        "Visit_ID": 2000 + i,
        "Date": fake.date_between(start_date="-1y", end_date="today").strftime("%Y-%m-%d"),
        "Patient_Name": fake.name(),
        "Age": random.randint(18, 80),
        "Gender": random.choice(["Male", "Female"]),
        "Diagnosis": random.choice(diagnoses),
        "Treatment": random.choice(treatments),
        "Doctor": random.choice(doctors),
        "Treatment_Cost": round(random.uniform(100, 15000), 2),
        "Payment_Method": random.choice(payment_methods),
        "Hospital_Location": random.choice(hospital_locations)
    }
    data.append(record) # Append the generated record to the list

# Convert to DataFrame
df = pd.DataFrame(data)

# %% [markdown]
# ## 1️⃣ Load JSON Data into a Pandas DataFrame

# %%
# convert to dataframe
df=pd.DataFrame(data)
# head of the df
df.head()
# Out:
#    Visit_ID        Date     Patient_Name  Age  Gender      Diagnosis  \
# 0      2001  2024-10-09     Joseph Perry   56    Male         Asthma
# 1      2002  2024-07-23  Emily Russo PhD   57  Female  Heart Disease
# 2      2003  2024-07-06        John Cook   74  Female      Arthritis
# 3      2004  2025-01-09        Seth York   32    Male   Hypertension
# 4      2005  2024-04-22      Lisa Lowery   19  Female  Heart Disease
#
#                    Treatment        Doctor  Treatment_Cost Payment_Method  \
# 0            Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 1            Insulin Therapy  Dr. Martinez         2927.30           Cash
# 2  Blood Pressure Medication    Dr. Wilson         8413.13     Debit Card
# 3            Insulin Therapy       Dr. Lee         7426.62           Cash
# 4            Cardiac Surgery     Dr. Smith        14435.85     Debit Card
#
#   Hospital_Location
# 0           Houston
# 1          New York
# 2          New York
# 3           Houston
# 4           Chicago

# %%
df.tail()
# Out:
#     Visit_ID        Date        Patient_Name  Age  Gender      Diagnosis  \
# 95      2096  2025-01-24          Brian Bush   22    Male       Diabetes
# 96      2097  2024-05-08         Jacob Wiley   54    Male   Hypertension
# 97      2098  2024-06-07           Megan Lee   29  Female         Asthma
# 98      2099  2025-01-17     Morgan Saunders   72  Female  Heart Disease
# 99      2100  2025-01-23  Christian Cisneros   63    Male         Asthma
#
#                     Treatment        Doctor  Treatment_Cost Payment_Method  \
# 95  Blood Pressure Medication     Dr. Smith         2597.45     Debit Card
# 96            Inhaler Therapy       Dr. Lee         8616.86     Debit Card
# 97            Inhaler Therapy  Dr. Martinez        13008.28    Credit Card
# 98            Insulin Therapy       Dr. Lee         1538.22           Cash
# 99            Cardiac Surgery  Dr. Martinez         2860.35      Insurance
#
#    Hospital_Location
# 95          New York
# 96          New York
# 97           Chicago
# 98       Los Angeles
# 99           Chicago

# %% [markdown]
# ## 2️⃣ Display DataFrame Information

# %%
# more info in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Visit_ID           100 non-null    int64
#  1   Date               100 non-null    object
#  2   Patient_Name       100 non-null    object
#  3   Age                100 non-null    int64
#  4   Gender             100 non-null    object
#  5   Diagnosis          100 non-null    object
#  6   Treatment          100 non-null    object
#  7   Doctor             100 non-null    object
#  8   Treatment_Cost     100 non-null    float64
#  9   Payment_Method     100 non-null    object
#  10  Hospital_Location  100 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 8.7+ KB

# %% [markdown]
# ## 3️⃣ Check for Missing Values and Fill Them

# %%
# checking NaN values
df.isnull().sum()
# Out:
# Visit_ID             0
# Date                 0
# Patient_Name         0
# Age                  0
# Gender               0
# Diagnosis            0
# Treatment            0
# Doctor               0
# Treatment_Cost       0
# Payment_Method       0
# Hospital_Location    0
# dtype: int64

# %% [markdown]
# There is no missing values

# %% [markdown]
# # <span style="color:red;">NB</span>
#  <span style="color:darkorange;">I will be using df.head(2) just to have an overview of the dataset instead of scrolling up and down every now and then</span>

# %% [markdown]
# ## 4️⃣ Convert Date Column to Datetime Format

# %%
df.head(2)
# Out:
#    Visit_ID        Date     Patient_Name  Age  Gender      Diagnosis  \
# 0      2001  2024-10-09     Joseph Perry   56    Male         Asthma
# 1      2002  2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#          Treatment        Doctor  Treatment_Cost Payment_Method  \
# 0  Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 1  Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#   Hospital_Location
# 0           Houston
# 1          New York

# %%
# convert column 'Date' into datetime data type
df['Date']=pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Visit_ID           100 non-null    int64
#  1   Date               100 non-null    datetime64[ns]
#  2   Patient_Name       100 non-null    object
#  3   Age                100 non-null    int64
#  4   Gender             100 non-null    object
#  5   Diagnosis          100 non-null    object
#  6   Treatment          100 non-null    object
#  7   Doctor             100 non-null    object
#  8   Treatment_Cost     100 non-null    float64
#  9   Payment_Method     100 non-null    object
#  10  Hospital_Location  100 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(7)
# memory usage: 8.7+ KB

# %% [markdown]
# 'Date' column converted to datetime dtype

# %% [markdown]
# ## 5️⃣ Set Visit_ID as Index

# %%
df.head(2)
# Out:
#    Visit_ID       Date     Patient_Name  Age  Gender      Diagnosis  \
# 0      2001 2024-10-09     Joseph Perry   56    Male         Asthma
# 1      2002 2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#          Treatment        Doctor  Treatment_Cost Payment_Method  \
# 0  Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 1  Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#   Hospital_Location
# 0           Houston
# 1          New York

# %% [markdown]
# Notice we have an index starting from 0

# %%
# setting Visit_ID' as index
df.set_index('Visit_ID', inplace=True)

# %%
df.head(2)
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#                 Treatment        Doctor  Treatment_Cost Payment_Method  \
# Visit_ID
# 2001      Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 2002      Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#          Hospital_Location
# Visit_ID
# 2001               Houston
# 2002              New York

# %% [markdown]
# Now we have and index as 'Visit_ID'

# %% [markdown]
# ## 6️⃣ Find Unique Diagnoses

# %%
# display aal unique diagnosis types in the dataset
df['Diagnosis'].unique()
# Out:
# array(['Asthma', 'Heart Disease', 'Arthritis', 'Hypertension', 'Diabetes'],
#       dtype=object)

# %% [markdown]
# ## 7️⃣ Count the Number of Patients by Gender

# %%
df.head(2)
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#                 Treatment        Doctor  Treatment_Cost Payment_Method  \
# Visit_ID
# 2001      Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 2002      Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#          Hospital_Location
# Visit_ID
# 2001               Houston
# 2002              New York

# %%
# number of patients by gender
df['Gender'].value_counts()
# Out:
# Gender
# Female    53
# Male      47
# Name: count, dtype: int64

# %% [markdown]
# ## 8️⃣ Calculate the Average Age of Patients

# %%
df.head()
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
# 2003     2024-07-06        John Cook   74  Female      Arthritis
# 2004     2025-01-09        Seth York   32    Male   Hypertension
# 2005     2024-04-22      Lisa Lowery   19  Female  Heart Disease
#
#                           Treatment        Doctor  Treatment_Cost  \
# Visit_ID
# 2001                Inhaler Therapy   Dr. Johnson         7745.44
# 2002                Insulin Therapy  Dr. Martinez         2927.30
# 2003      Blood Pressure Medication    Dr. Wilson         8413.13
# 2004                Insulin Therapy       Dr. Lee         7426.62
# 2005                Cardiac Surgery     Dr. Smith        14435.85
#
#          Payment_Method Hospital_Location
# Visit_ID
# 2001         Debit Card           Houston
# 2002               Cash          New York
# 2003         Debit Card          New York
# 2004               Cash           Houston
# 2005         Debit Card           Chicago

# %%
# avearge age of patients 
df['Age'].mean()
# Out:
# 49.92

# %% [markdown]
# ## 9️⃣ Find the Most Common Diagnosis

# %%
df.head(2)
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#                 Treatment        Doctor  Treatment_Cost Payment_Method  \
# Visit_ID
# 2001      Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 2002      Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#          Hospital_Location
# Visit_ID
# 2001               Houston
# 2002              New York

# %%
# most common Diagnosis (mode)
df['Diagnosis'].mode()[0]
# Out:
# 'Asthma'

# %%
# most common diagnosis
df['Diagnosis'].value_counts().idxmax()
# Out:
# 'Asthma'

# %% [markdown]
# ## 🔟 Find Total Treatment Cost by Payment Method

# %%
df.head(2)
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#                 Treatment        Doctor  Treatment_Cost Payment_Method  \
# Visit_ID
# 2001      Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 2002      Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#          Hospital_Location
# Visit_ID
# 2001               Houston
# 2002              New York

# %%
# # Grouping the dataframe by 'Payment_Method' and summing the 'Treatment_Cost' for each payment method
df.groupby('Payment_Method')['Treatment_Cost'].sum()
# Out:
# Payment_Method
# Cash           204941.21
# Credit Card    193524.41
# Debit Card     188001.16
# Insurance      162305.33
# Name: Treatment_Cost, dtype: float64

# %% [markdown]
# ## 1️⃣1️⃣ Find the Patient with the Highest Treatment Cost

# %%
df.head(2)
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#                 Treatment        Doctor  Treatment_Cost Payment_Method  \
# Visit_ID
# 2001      Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 2002      Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#          Hospital_Location
# Visit_ID
# 2001               Houston
# 2002              New York

# %%
# Select the row(s) where Treatment_Cost is at its maximum
df[df['Treatment_Cost']==df['Treatment_Cost'].max()]
# Out:
#                Date Patient_Name  Age Gender      Diagnosis  \
# Visit_ID
# 2079     2024-04-19    Jason Fox   62   Male  Heart Disease
#
#                           Treatment      Doctor  Treatment_Cost  \
# Visit_ID
# 2079      Blood Pressure Medication  Dr. Wilson        14921.23
#
#          Payment_Method Hospital_Location
# Visit_ID
# 2079               Cash           Houston

# %% [markdown]
# ## 1️⃣2️⃣ Find All Patients Diagnosed with Diabetes

# %%
df.head(2)
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#                 Treatment        Doctor  Treatment_Cost Payment_Method  \
# Visit_ID
# 2001      Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 2002      Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#          Hospital_Location
# Visit_ID
# 2001               Houston
# 2002              New York

# %%
# filtering all rows where 'Diagnosis' is Diabetes
df[df['Diagnosis']=='Diabetes']
# Out:
#                Date       Patient_Name  Age  Gender Diagnosis  \
# Visit_ID
# 2006     2024-06-04      Deborah Stone   74  Female  Diabetes
# 2008     2024-04-22     Jonathan Jones   49    Male  Diabetes
# 2016     2024-07-29     Kyle Blackwell   69  Female  Diabetes
# 2018     2024-03-03  Hunter Washington   54    Male  Diabetes
# 2020     2024-10-14      Audrey Jensen   23    Male  Diabetes
# 2021     2024-12-09  Michele Carpenter   65    Male  Diabetes
# 2025     2025-01-17     Andrew Murillo   51    Male  Diabetes
# 2031     2024-04-19     Brian Williams   69  Female  Diabetes
# 2038     2024-10-07   Michael Campbell   70    Male  Diabetes
# 2039     2024-11-20      Melinda Myers   37    Male  Diabetes
# 2043     2024-08-09       Andrea Brown   48  Female  Diabetes
# 2056     2024-06-10       Jessica Lane   42  Female  Diabetes
# 2062     2024-11-15      Cathy Coleman   31  Female  Diabetes
# 2067     2024-06-15        James Davis   38    Male  Diabetes
# 2069     2024-08-12           Ryan Gay   43  Female  Diabetes
# 2070     2024-04-18        Scott Brown   61  Female  Diabetes
# 2082     2024-05-15     Dennis Sanchez   33    Male  Diabetes
# 2092     2025-02-17      Darlene White   31    Male  Diabetes
# 2093     2024-09-10         Tony Ortiz   50  Female  Diabetes
# 2096     2025-01-24         Brian Bush   22    Male  Diabetes
#
#                           Treatment        Doctor  Treatment_Cost  \
# Visit_ID
# 2006               Physical Therapy       Dr. Lee         9994.55
# 2008                Insulin Therapy  Dr. Martinez         8663.73
# 2016                Cardiac Surgery    Dr. Wilson         7658.16
# 2018                Cardiac Surgery    Dr. Wilson        11915.48
# 2020                Insulin Therapy     Dr. Smith        14731.98
# 2021      Blood Pressure Medication       Dr. Lee         2599.23
# 2025      Blood Pressure Medication    Dr. Wilson         4030.85
# 2031                Inhaler Therapy       Dr. Lee         1320.28
# 2038               Physical Therapy  Dr. Martinez        11305.05
# 2039                Insulin Therapy       Dr. Lee        13676.87
# 2043               Physical Therapy       Dr. Lee        13107.58
# 2056               Physical Therapy       Dr. Lee         4402.40
# 2062                Inhaler Therapy       Dr. Lee        13623.49
# 2067                Inhaler Therapy       Dr. Lee         2350.97
# 2069                Insulin Therapy     Dr. Smith         7935.12
# 2070      Blood Pressure Medication    Dr. Wilson         8005.35
# 2082               Physical Therapy  Dr. Martinez         2217.00
# 2092      Blood Pressure Medication    Dr. Wilson         8428.17
# 2093                Cardiac Surgery   Dr. Johnson         4599.64
# 2096      Blood Pressure Medication     Dr. Smith         2597.45
#
#          Payment_Method Hospital_Location
# Visit_ID
# 2006        Credit Card       Los Angeles
# 2008         Debit Card       Los Angeles
# 2016         Debit Card       Los Angeles
# 2018          Insurance       Los Angeles
# 2020        Credit Card       Los Angeles
# 2021          Insurance           Chicago
# 2025               Cash       Los Angeles
# 2031        Credit Card          New York
# 2038         Debit Card          New York
# 2039          Insurance          New York
# 2043         Debit Card          New York
# 2056        Credit Card          New York
# 2062               Cash       Los Angeles
# 2067        Credit Card          New York
# 2069               Cash           Chicago
# 2070               Cash          New York
# 2082          Insurance       Los Angeles
# 2092        Credit Card           Houston
# 2093               Cash           Chicago
# 2096         Debit Card          New York

# %% [markdown]
# ## 1️⃣3️⃣ Count Visits by Hospital Location

# %%
df.head(2)
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#                 Treatment        Doctor  Treatment_Cost Payment_Method  \
# Visit_ID
# 2001      Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 2002      Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#          Hospital_Location
# Visit_ID
# 2001               Houston
# 2002              New York

# %%
# vists by hospital location 
df['Hospital_Location'].value_counts()
# Out:
# Hospital_Location
# New York       33
# Chicago        25
# Houston        22
# Los Angeles    20
# Name: count, dtype: int64

# %% [markdown]
# ## 1️⃣4️⃣ Find All Patients Who Paid with Cash

# %%
df.head(2)
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#                 Treatment        Doctor  Treatment_Cost Payment_Method  \
# Visit_ID
# 2001      Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 2002      Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#          Hospital_Location
# Visit_ID
# 2001               Houston
# 2002              New York

# %%
# filtering all row where 'Payment_Method' is 'Cash'
df[df['Payment_Method']=='Cash']
# Out:
#                Date         Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2002     2024-07-23      Emily Russo PhD   57  Female  Heart Disease
# 2004     2025-01-09            Seth York   32    Male   Hypertension
# 2023     2024-10-22      Ms. Jane Gordon   50    Male      Arthritis
# 2025     2025-01-17       Andrew Murillo   51    Male       Diabetes
# 2028     2025-01-02     Veronica Vincent   65  Female         Asthma
# 2029     2024-09-17       Jacob Thompson   42    Male  Heart Disease
# 2030     2025-01-09     Zachary Anderson   72  Female         Asthma
# 2035     2024-03-17    Carolyn Contreras   36  Female      Arthritis
# 2037     2024-03-16      Michael Gregory   46    Male         Asthma
# 2041     2024-10-16          Deanna Ross   69    Male         Asthma
# 2051     2024-08-09       Jacob Gonzales   61    Male      Arthritis
# 2058     2024-05-23        Deborah Ortiz   52  Female      Arthritis
# 2059     2024-05-30           John Knapp   50  Female   Hypertension
# 2062     2024-11-15        Cathy Coleman   31  Female       Diabetes
# 2066     2024-07-03           Sean Jones   70    Male   Hypertension
# 2068     2024-11-07  Mrs. Shannon Wright   35  Female  Heart Disease
# 2069     2024-08-12             Ryan Gay   43  Female       Diabetes
# 2070     2024-04-18          Scott Brown   61  Female       Diabetes
# 2073     2024-06-30        Darin Schultz   25  Female      Arthritis
# 2079     2024-04-19            Jason Fox   62    Male  Heart Disease
# 2080     2024-11-12          James Smith   25    Male      Arthritis
# 2081     2025-01-16          Amy Russell   78    Male      Arthritis
# 2086     2024-06-14        Nicole Pierce   18  Female         Asthma
# 2088     2024-05-07    Ricardo Hernandez   41  Female      Arthritis
# 2093     2024-09-10           Tony Ortiz   50  Female       Diabetes
# 2095     2024-12-21        Sherry Mathis   68    Male   Hypertension
# 2099     2025-01-17      Morgan Saunders   72  Female  Heart Disease
#
#                           Treatment        Doctor  Treatment_Cost  \
# Visit_ID
# 2002                Insulin Therapy  Dr. Martinez         2927.30
# 2004                Insulin Therapy       Dr. Lee         7426.62
# 2023      Blood Pressure Medication     Dr. Smith          192.86
# 2025      Blood Pressure Medication    Dr. Wilson         4030.85
# 2028      Blood Pressure Medication       Dr. Lee         9616.49
# 2029                Cardiac Surgery   Dr. Johnson         6723.30
# 2030               Physical Therapy  Dr. Martinez         8948.51
# 2035      Blood Pressure Medication   Dr. Johnson         9694.65
# 2037                Inhaler Therapy       Dr. Lee        10010.27
# 2041                Cardiac Surgery    Dr. Wilson        14280.89
# 2051                Cardiac Surgery    Dr. Wilson        10622.48
# 2058      Blood Pressure Medication     Dr. Smith        11620.93
# 2059                Inhaler Therapy  Dr. Martinez         5490.94
# 2062                Inhaler Therapy       Dr. Lee        13623.49
# 2066                Cardiac Surgery  Dr. Martinez         7402.26
# 2068      Blood Pressure Medication  Dr. Martinez         4308.57
# 2069                Insulin Therapy     Dr. Smith         7935.12
# 2070      Blood Pressure Medication    Dr. Wilson         8005.35
# 2073               Physical Therapy   Dr. Johnson         4528.94
# 2079      Blood Pressure Medication    Dr. Wilson        14921.23
# 2080                Insulin Therapy  Dr. Martinez        10751.09
# 2081      Blood Pressure Medication  Dr. Martinez         2207.30
# 2086               Physical Therapy  Dr. Martinez        11599.71
# 2088                Inhaler Therapy   Dr. Johnson         5087.77
# 2093                Cardiac Surgery   Dr. Johnson         4599.64
# 2095                Insulin Therapy   Dr. Johnson         6846.43
# 2099                Insulin Therapy       Dr. Lee         1538.22
#
#          Payment_Method Hospital_Location
# Visit_ID
# 2002               Cash          New York
# 2004               Cash           Houston
# 2023               Cash           Houston
# 2025               Cash       Los Angeles
# 2028               Cash           Houston
# 2029               Cash          New York
# 2030               Cash          New York
# 2035               Cash       Los Angeles
# 2037               Cash       Los Angeles
# 2041               Cash          New York
# 2051               Cash           Chicago
# 2058               Cash           Houston
# 2059               Cash           Chicago
# 2062               Cash       Los Angeles
# 2066               Cash           Chicago
# 2068               Cash          New York
# 2069               Cash           Chicago
# 2070               Cash          New York
# 2073               Cash           Chicago
# 2079               Cash           Houston
# 2080               Cash          New York
# 2081               Cash       Los Angeles
# 2086               Cash          New York
# 2088               Cash           Houston
# 2093               Cash           Chicago
# 2095               Cash       Los Angeles
# 2099               Cash       Los Angeles

# %% [markdown]
# ## 1️⃣5️⃣ Get the Top 5 Most Expensive Treatments

# %%
df.head(2)
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#                 Treatment        Doctor  Treatment_Cost Payment_Method  \
# Visit_ID
# 2001      Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 2002      Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#          Hospital_Location
# Visit_ID
# 2001               Houston
# 2002              New York

# %%
#  Select the top 5 rows with the highest treatment costs
df.nlargest(5, "Treatment_Cost")
# Out:
#                Date   Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2079     2024-04-19      Jason Fox   62    Male  Heart Disease
# 2085     2024-02-28    Keith Ortiz   61  Female   Hypertension
# 2020     2024-10-14  Audrey Jensen   23    Male       Diabetes
# 2077     2024-05-06    Erin Bailey   78  Female  Heart Disease
# 2005     2024-04-22    Lisa Lowery   19  Female  Heart Disease
#
#                           Treatment        Doctor  Treatment_Cost  \
# Visit_ID
# 2079      Blood Pressure Medication    Dr. Wilson        14921.23
# 2085      Blood Pressure Medication  Dr. Martinez        14901.58
# 2020                Insulin Therapy     Dr. Smith        14731.98
# 2077                Inhaler Therapy  Dr. Martinez        14528.79
# 2005                Cardiac Surgery     Dr. Smith        14435.85
#
#          Payment_Method Hospital_Location
# Visit_ID
# 2079               Cash           Houston
# 2085         Debit Card          New York
# 2020        Credit Card       Los Angeles
# 2077        Credit Card          New York
# 2005         Debit Card           Chicago

# %% [markdown]
# ## 1️⃣6️⃣How many visits occurred each month?

# %%
df.head(2)
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#                 Treatment        Doctor  Treatment_Cost Payment_Method  \
# Visit_ID
# 2001      Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 2002      Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#          Hospital_Location
# Visit_ID
# 2001               Houston
# 2002              New York

# %% [markdown]
# First of all change 'Date' colum into datetime dtype and create a column for mont

# %%
# conver 'Date' into datetime dtype
df['Month']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].dt.month

# %%
df.head(2)
# Out:
#                Date     Patient_Name  Age  Gender      Diagnosis  \
# Visit_ID
# 2001     2024-10-09     Joseph Perry   56    Male         Asthma
# 2002     2024-07-23  Emily Russo PhD   57  Female  Heart Disease
#
#                 Treatment        Doctor  Treatment_Cost Payment_Method  \
# Visit_ID
# 2001      Inhaler Therapy   Dr. Johnson         7745.44     Debit Card
# 2002      Insulin Therapy  Dr. Martinez         2927.30           Cash
#
#          Hospital_Location  Month
# Visit_ID
# 2001               Houston     10
# 2002              New York      7

# %% [markdown]
# Notice the new column 'Month' created

# %%
# visits per month
df['Month'].value_counts()
# Out:
# Month
# 1     15
# 6     11
# 9     10
# 10     9
# 7      9
# 11     8
# 2      8
# 5      8
# 8      7
# 4      6
# 3      5
# 12     4
# Name: count, dtype: int64
